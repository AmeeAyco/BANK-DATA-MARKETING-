# %%
import pandas as pd
import numpy as np

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 4.6 MB/s
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.2)
# Collecting numpy>=1.17.3
#   Downloading numpy-1.21.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 60.9 MB/s
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: numpy, pandas
# Successfully installed numpy-1.21.5 pandas-1.3.5

# %%
print("Pandas Version: %s" % pd.__version__)
# Out:
# Pandas Version: 1.3.5

# %%
print("NumPy Version: %s" % np.__version__)
# Out:
# NumPy Version: 1.21.5

# %%
# CSV Data were read from the folder. Append all dataset    
missing=["No Info","None","none"] 
BankData = ["bank.csv", "bank-full.csv", "bank-additional.csv","bank-additional-full.csv"] 
df_Bank_Data = pd.DataFrame()
for BankData in BankData:
   df_Bank_Data = df_Bank_Data.append(pd.read_csv(BankData,na_values=missing,sep=";"))

# %%
#output first 5 rows just to see the first 5 values of the dataset
df_Bank_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95039 entries, 0 to 41187
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             95039 non-null  int64
#  1   job             95039 non-null  object
#  2   marital         95039 non-null  object
#  3   education       95039 non-null  object
#  4   default         95039 non-null  object
#  5   balance         49732 non-null  float64
#  6   housing         95039 non-null  object
#  7   loan            95039 non-null  object
#  8   contact         95039 non-null  object
#  9   day             49732 non-null  float64
#  10  month           95039 non-null  object
#  11  duration        95039 non-null  int64
#  12  campaign        95039 non-null  int64
#  13  pdays           95039 non-null  int64
#  14  previous        95039 non-null  int64
#  15  poutcome        95039 non-null  object
#  16  y               95039 non-null  object
#  17  day_of_week     45307 non-null  object
#  18  emp.var.rate    45307 non-null  float64
#  19  cons.price.idx  45307 non-null  float64
#  20  cons.conf.idx   45307 non-null  float64
#  21  euribor3m       45307 non-null  float64
#  22  nr.employed     45307 non-null  float64
# dtypes: float64(7), int64(5), object(11)
# memory usage: 17.4+ MB

# %%
df_Bank_Data.describe().T
# Out:
#                   count         mean          std       min       25%  \
# age             95039.0    40.516377    10.528531    17.000    32.000
# balance         49732.0  1367.761562  3041.608766 -8019.000    72.000
# day             49732.0    15.816315     8.315680     1.000     8.000
# duration        95039.0   258.432149   258.276965     0.000   103.000
# campaign        95039.0     2.670388     2.940562     1.000     1.000
# pdays           95039.0   479.756595   483.843861    -1.000    -1.000
# previous        95039.0     0.385084     1.679209     0.000     0.000
# emp.var.rate    45307.0     0.082166     1.570231    -3.400    -1.800
# cons.price.idx  45307.0    93.576032     0.578881    92.201    93.075
# cons.conf.idx   45307.0   -40.502282     4.625101   -50.800   -42.700
# euribor3m       45307.0     3.621297     1.734350     0.634     1.344
# nr.employed     45307.0  5166.985525    72.380791  4963.600  5099.100
#
#                      50%       75%         max
# age               39.000    48.000      98.000
# balance          448.000  1431.000  102127.000
# day               16.000    21.000      31.000
# duration         180.000   319.000    4918.000
# campaign           2.000     3.000      63.000
# pdays            245.000   999.000     999.000
# previous           0.000     0.000     275.000
# emp.var.rate       1.100     1.400       1.400
# cons.price.idx    93.749    93.994      94.767
# cons.conf.idx    -41.800   -36.400     -26.900
# euribor3m          4.857     4.961       5.045
# nr.employed     5191.000  5228.100    5228.100

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 4.7 MB/s
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.4.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 60.5 MB/s
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (3.0.6)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.28.5-py3-none-any.whl (890 kB)
#      |████████████████████████████████| 890 kB 63.4 MB/s
# Requirement already satisfied: numpy>=1.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (1.21.5)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 53.3 MB/s
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.28.5 kiwisolver-1.3.2 matplotlib-3.5.1 pillow-8.4.0

# %%
# !pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.7/site-packages (3.5.1)
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      |████████████████████████████████| 292 kB 4.7 MB/s
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (4.28.5)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: numpy>=1.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: pandas>=0.23 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from seaborn) (1.3.5)
# Collecting scipy>=1.0
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 68.3 MB/s
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: scipy, seaborn
# Successfully installed scipy-1.7.3 seaborn-0.11.2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f, axes = plt.subplots(1, 12, figsize=(15,8))
f.tight_layout()
font={'weight' : 'bold',
        'size': 12}


df_Bank_Data.hist(figsize=(100,100),color='#A3D9FF',ax=axes[0], grid=False)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   import sys
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'balance'}>,
#         <AxesSubplot:title={'center':'day'}>],
#        [<AxesSubplot:title={'center':'duration'}>,
#         <AxesSubplot:title={'center':'campaign'}>,
#         <AxesSubplot:title={'center':'pdays'}>],
#        [<AxesSubplot:title={'center':'previous'}>,
#         <AxesSubplot:title={'center':'emp.var.rate'}>,
#         <AxesSubplot:title={'center':'cons.price.idx'}>],
#        [<AxesSubplot:title={'center':'cons.conf.idx'}>,
#         <AxesSubplot:title={'center':'euribor3m'}>,
#         <AxesSubplot:title={'center':'nr.employed'}>]], dtype=object)
